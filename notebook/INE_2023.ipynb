# %%
import pandas as pd

# %%
Ine_2023 = pd.read_csv('../2023.csv', encoding='latin1', sep="\t")
Ine_2023.head()
# Out:
#   Totales Territoriales Comunidades y Ciudades Autónomas Provincias  \
# 0        Total Nacional                              NaN        NaN
# 1        Total Nacional                              NaN        NaN
# 2        Total Nacional                              NaN        NaN
# 3        Total Nacional                              NaN        NaN
# 4        Total Nacional                              NaN        NaN
#
#   Viajeros y pernoctaciones Residencia: Nivel 1          Residencia: Nivel 2  \
# 0                   Viajero              Total                           NaN
# 1                   Viajero              Total          Residentes en España
# 2                   Viajero              Total   Residentes en el Extranjero
# 3            Pernoctaciones              Total                           NaN
# 4            Pernoctaciones              Total          Residentes en España
#
#    Periodo       Total
# 0  2023M09  11.635.208
# 1  2023M09   5.132.262
# ...

# %%
ine = Ine_2023.copy()
type(INE)
# Out:
# pandas.core.frame.DataFrame

# %%
ine.iloc[0:20]
# Out:
#    Totales Territoriales Comunidades y Ciudades Autónomas  Provincias  \
# 0         Total Nacional                              NaN         NaN
# 1         Total Nacional                              NaN         NaN
# 2         Total Nacional                              NaN         NaN
# 3         Total Nacional                              NaN         NaN
# 4         Total Nacional                              NaN         NaN
# 5         Total Nacional                              NaN         NaN
# 6         Total Nacional                     01 Andalucía         NaN
# 7         Total Nacional                     01 Andalucía         NaN
# 8         Total Nacional                     01 Andalucía         NaN
# 9         Total Nacional                     01 Andalucía         NaN
# 10        Total Nacional                     01 Andalucía         NaN
# 11        Total Nacional                     01 Andalucía         NaN
# ...

# %% [markdown]
# Observando la tabla no me la ordenado correctamente y es dificil su visualización. Por lo que, voy a recurrir a la herramienta 'pivot' para reorganizar y analizar los datos en un formato más adecuado.

# %%
tabla_pivot= tabla.pivot_table(index=['Totales'])

# %%
import pandas as pd

# Tu DataFrame original
# ...

# Utiliza pivot_table para reorganizar los datos
tabla_pivot = tabla.pivot_table(index=['Totales Territoriales', 'Comunidades y Ciudades Autónomas', 'Provincias', 'Periodo'], columns='Residencia: Nivel 2', values='Total', aggfunc='sum')

# Restablece el índice para obtener la estructura deseada
tabla_pivot = tabla_pivot.reset_index()

# Cambia el nombre de las columnas para que coincidan con la estructura deseada
tabla_pivot.columns = ['Viajero', 'Pernoctaciones', 'Residentes en España', 'Residentes en el Extranjero', 'Total', 'Residentes en España', 'Residentes en el Extranjero']

# Elimina el nombre de las columnas para que la primera fila sea el encabezado
tabla_pivot.columns.name = None

# Reorganiza las columnas según la estructura deseada
tabla_pivot = tabla_pivot[['Viajero', 'Pernoctaciones', 'Residentes en España', 'Residentes en el Extranjero', 'Total', 'Residentes en España', 'Residentes en el Extranjero', 'Periodo']]

# Muestra el resultado
print(tabla_pivot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 13
#      10 tabla_pivot = tabla_pivot.reset_index()
#      12 # Cambia el nombre de las columnas para que coincidan con la estructura deseada
# ---> 13 tabla_pivot.columns = ['Viajero', 'Pernoctaciones', 'Residentes en España', 'Residentes en el Extranjero', 'Total', 'Residentes en España', 'Residentes en el Extranjero']
#      15 # Elimina el nombre de las columnas para que la primera fila sea el encabezado
#      16 tabla_pivot.columns.name = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# ...

# %%
ine.iloc[7]
# Out:
# Totales Territoriales                     Total Nacional
# Comunidades y Ciudades Autónomas            01 Andalucía
# Provincias                                           NaN
# Viajeros y pernoctaciones                        Viajero
# Residencia: Nivel 1                               Total
# Residencia: Nivel 2                 Residentes en España
# Periodo                                          2023M09
# Total                                          1.044.697
# Name: 7, dtype: object

# %%
ine.keys()
# Out:
# Index(['Totales Territoriales', 'Comunidades y Ciudades Autónomas',
#        'Provincias', 'Viajeros y pernoctaciones', 'Residencia: Nivel 1',
#        'Residencia: Nivel 2', 'Periodo', 'Total'],
#       dtype='object')

# %%
#Agrupar por provincias y coger los semestres. Estudiar la de 2022 y juntarlas, sumar los datos.

# %%
Ine_primersemestre = pd.read_csv('../2022_primersemestre.csv', encoding='latin1', sep="\t")
Ine_primersemestre.head()
# Out:
#   Totales Territoriales Comunidades y Ciudades Autónomas Provincias  \
# 0        Total Nacional                              NaN        NaN
# 1        Total Nacional                              NaN        NaN
# 2        Total Nacional                              NaN        NaN
# 3        Total Nacional                              NaN        NaN
# 4        Total Nacional                              NaN        NaN
#
#   Viajeros y pernoctaciones Residencia: Nivel 1 Residencia: Nivel 2  Periodo  \
# 0                   Viajero              Total                  NaN  2022M06
# 1                   Viajero              Total                  NaN  2022M05
# 2                   Viajero              Total                  NaN  2022M04
# 3                   Viajero              Total                  NaN  2022M03
# 4                   Viajero              Total                  NaN  2022M02
#
#         Total
# 0  10.990.468
# 1   9.920.671
# 2   8.689.822
# 3   6.061.398
# 4   5.133.961

# %%
Ine_primersemestre.shape
# Out:
# (2520, 8)

# %%
Ine_segundosemestre = pd.read_csv('../2022_segundosemestre.csv', encoding='latin1', sep="\t")
Ine_segundosemestre.head()
# Out:
#   Totales Territoriales Comunidades y Ciudades Autónomas Provincias  \
# 0        Total Nacional                              NaN        NaN
# 1        Total Nacional                              NaN        NaN
# 2        Total Nacional                              NaN        NaN
# 3        Total Nacional                              NaN        NaN
# 4        Total Nacional                              NaN        NaN
#
#   Viajeros y pernoctaciones Residencia: Nivel 1 Residencia: Nivel 2  Periodo  \
# 0                   Viajero              Total                  NaN  2022M12
# 1                   Viajero              Total                  NaN  2022M11
# 2                   Viajero              Total                  NaN  2022M10
# 3                   Viajero              Total                  NaN  2022M09
# 4                   Viajero              Total                  NaN  2022M08
#
#         Total
# 0   6.054.556
# 1   6.284.698
# 2   9.743.259
# 3  11.050.305
# 4  12.889.916

# %%
Ine_segundosemestre.shape
# Out:
# (2520, 8)

# %% [markdown]
# #### Limpiar nombre de columnas y renombrar

# %% [markdown]
# ## CSV DESDE 1999

# %%
INE_original= pd.read_csv('../2074.csv', sep="\t")
INE_original.head()
# Out:
#   Totales Territoriales Comunidades y Ciudades Autónomas Provincias  \
# 0        Total Nacional                              NaN        NaN
# 1        Total Nacional                              NaN        NaN
# 2        Total Nacional                              NaN        NaN
# 3        Total Nacional                              NaN        NaN
# 4        Total Nacional                              NaN        NaN
#
#   Viajeros y pernoctaciones Residencia: Nivel 1 Residencia: Nivel 2  Periodo  \
# 0                   Viajero              Total                  NaN  2023M09
# 1                   Viajero              Total                  NaN  2023M08
# 2                   Viajero              Total                  NaN  2023M07
# 3                   Viajero              Total                  NaN  2023M06
# 4                   Viajero              Total                  NaN  2023M05
#
#         Total
# 0  11.635.208
# 1  13.196.928
# 2  12.664.627
# 3  11.507.055
# 4  10.645.074

# %%
INE_original.keys()
# Out:
# Index(['Totales Territoriales', 'Comunidades y Ciudades Autónomas',
#        'Provincias', 'Viajeros y pernoctaciones', 'Residencia: Nivel 1',
#        'Residencia: Nivel 2', 'Periodo', 'Total'],
#       dtype='object')

# %%
INE = INE_original.copy()
type(INE)
# Out:
# pandas.core.frame.DataFrame
