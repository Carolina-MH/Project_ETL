# %% [markdown]
# Realizar un análisis y comparación de las tres tablas que has extraído: una tabla con datos de viajeros y pernoctaciones por provincias, otra con datos climáticos por provincias y otra con datos de población por provincias. Esto te permitirá realizar análisis y obtener información interesante al cruzar estos datos.

# %% [markdown]
# Primero importaré los datos en este nuevo JN desde los tres JN originales:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
viajeros= pd.read_csv('export/viajeros.csv')
pernoctaciones= pd.read_csv('export/pernoctaciones.csv')

# %% [markdown]
# ## Exploración inicial

# %%
viajeros = viajeros.fillna('-')

# %%
pernoctaciones = viajeros.fillna('-')

# %%
viajeros = viajeros.rename(columns=lambda x: f"Viajeros_{x}" if x != 'Periodo' else x)

'''
Si el nombre de la columna (x) no es igual a 'Periodo', agrega el prefijo "Viajeros_" al 
nombre original (x) utilizando una f-string (f"Viajeros_{x}"). Esto significa que todas 
las columnas, excepto 'Periodo', obtendrán un prefijo "Viajeros_" en sus nombres.
'''

pernoctaciones = pernoctaciones.rename(columns=lambda x: f"Pernoctaciones_{x}" if x != 'Periodo' else x)

# %%
ine_22 = pd.concat([viajeros, pernoctaciones], axis=1)
ine_22.head()
# Out:
#               Periodo Viajeros_Viajeros_2022M01  Viajeros_Viajeros_2022M01.1  \
# 0  Residencia_Nivel_2      Residentes en Espana  Residentes en el Extranjero
# 1          Provincias                         -                            -
# 2            A CORUÑA                    51.283                       10.804
# 3            ALBACETE                    15.963                        1.525
# 4            ALICANTE                    75.778                       49.765
#
#   Viajeros_Viajeros_2022M02  Viajeros_Viajeros_2022M02.1  \
# 0      Residentes en Espana  Residentes en el Extranjero
# 1                         -                            -
# 2                    72.223                       13.320
# 3                    20.754                        2.755
# 4                   133.494                       78.422
#
#   Viajeros_Viajeros_2022M03  Viajeros_Viajeros_2022M03.1  \
# 0      Residentes en Espana  Residentes en el Extranjero
# ...
